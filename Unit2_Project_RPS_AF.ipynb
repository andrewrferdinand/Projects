# %%
import getpass
## Prompt one user for an R/P/S input and hiding the entered value.

def validate_user_input(value_entered):
## Function to validate user input is either 'r','p','s','y','n'.
  allowed_user_input = ('r','p','s','y','n')
  ## Used a tuple as this is an immutable sequences of items. Its a fixed collections of data.

  if (value_entered.lower() == 'y/n'):
    while True:
      user_input = input("\nPress 'Y'' key to start or 'N' to quit: ")
      if user_input.lower() in allowed_user_input[3:]:
        return user_input.lower()
        break
      else:
        print("\nInvalid input. Please enter 'Y' or 'N'.")

  elif (value_entered.lower() == 'choice1'):
    while True:
      Player_1_message = "\n" + Player_1 + ", please enter your choice (Rock 'r', Paper 'p', Scissors 's': "
      user_input_player1 = getpass.getpass(Player_1_message)
      if user_input_player1.lower() in allowed_user_input[0:3]:
        return user_input_player1.lower()
        break
      else:
        print("\nInvalid input" + Player_1 + ". Please enter either 'r', 'p' or 's'.")

  elif (value_entered.lower() == 'choice2'):
    while True:
      Player_2_message = "\n" + Player_2 + ", please enter your choice (Rock 'r', Paper 'p', Scissors 's': "
      user_input_player2 = input(Player_2_message)
      if user_input_player2.lower() in allowed_user_input[0:3]:
        return user_input_player2.lower()
        break
      else:
        print("\nInvalid input" + Player_2 + ". Please enter either 'r', 'p' or 's'.")

print ("Welcome to Rock-Paper-Scissors game.")
print ("\nThe rules for playing Rock Paper Scissors are as follows:")
print ("  * This a two-player game. Each player will randomly choose one of three signs: Rock (made by entering 'r'), Paper (made by entering a 'p') and Scisors (made by entering an 's')")
print ("  * Player 1 will go first and choose one of three signs: Rock (made by entering 'r'), Paper (made by entering a 'p') and Scisors (made by entering an 's')")
print ("  * Player 2 will respond with one of three signs: Rock (made by entering 'r'), Paper (made by entering a 'p') and Scisors (made by entering an 's')")
print ("  * Remeber the rules:")
print ("    ** Rock beats Scissors")
print ("    ** Scissors beats Paper")
print ("    ** Paper beats Rock")

is_continue = validate_user_input('y/n')

# Check if the user wants to start the game
if is_continue == 'y':

  Player_1 = input("\nPlayer 1 please enter your name: ")
  while True:
    Player_2 = input("\nPlayer 2 please enter your name: ")
    if Player_2.lower() != Player_1.lower():
      break;
    else:
      print("\nBoth players cant have the same name. Please choose a differenert name.")

  print("\nLet's begin ....\n")

  while True:
    user_input_player1 = validate_user_input('choice1')
    user_input_player2 = validate_user_input('choice2')

    if (user_input_player1 == user_input_player2):
      print("\nIt's a tie!! Both players selected the same choice: '" + user_input_player2+ "'.")

    if (user_input_player1 == 'r'):
      if (user_input_player2 == 's'):
        print("\n" + Player_1, "entered '" + user_input_player1 + "' wins. Congratulations! Rock beats Scissors!")
      elif (user_input_player2 == 'p'):
        print("\n" + Player_1, "entered '" + user_input_player1 + "'. " + Player_2 + " wins. Congratulations! Paper beats Rock!")

    if (user_input_player1 == 's'):
      if (user_input_player2 == 'r'):
        print("\n" + Player_1, "entered '" + user_input_player1 + "'. " + Player_2 + " wins. Congratulations! Rock beats Scissors!")
      elif (user_input_player2 == 'p'):
        print("\n" + Player_1, "entered '" + user_input_player1 + "' wins. Congratulations! Scissors beats Paper!")

    if (user_input_player1 == 'p'):
      if (user_input_player2 == 'r'):
        print("\n" + Player_1, "entered '" + user_input_player1 + "' wins. Congratulations! Paper beats Rock!")
      elif (user_input_player2 == 's'):
        print("\n" + Player_1, "entered '" + user_input_player1 + "'. " + Player_2 + " wins. Congratulations! Scissors beats Paper!")

    is_continue_during_game = input("\nDo you wish to continie? (Y/N):")
    if (is_continue_during_game.lower() == 'n'):
      print("\nExiting game... Goodbye")
      break
    else:
      continue
elif (is_continue == 'n'):
  print("\nExiting game... Goodbye")
